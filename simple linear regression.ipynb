# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/Salary_Data.csv')

# %%
df.head(2)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.title('data table')
plt.xlabel('years of experience')
plt.ylabel('salary(lakhs per annum)');

# %%
x = df['YearsExperience']
y = df['Salary']

# %%
x_train , x_test ,y_train ,y_test = train_test_split(
    x,y,
    test_size=.3,
    random_state = 42
)

# %%
y_train.shape
# Out:
# (21,)

# %%
x_test.shape
# Out:
# (9,)

# %%
model = LinearRegression()
model.fit(x_train.values.reshape(21,1),y_train.values.reshape(21,1))
# Out:
# LinearRegression()

# %%
x_train = x_train.values.reshape(21,1)

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.plot(x_train,model.predict(x_train),c='r')

# %%
model.coef_
# Out:
# array([[9339.08172382]])

# %%
model.intercept_
# Out:
# array([25918.43833489])
